# %% [markdown]
# <a href="https://colab.research.google.com/github/Ujjwalbansaljss/watboo/blob/main/Ujjwal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Khatu Shyam Ji')
# Out:
# Khatu Shyam Ji

# %%
import matplotlib.pyplot as plt
import numpy as np
xpts =np.array([0,4])
ypts=np.array([0,100])
plt.plot(xpts, ypts)
